# %% [markdown]
# <a href="https://colab.research.google.com/github/subashini092/Assignments/blob/main/Covid_fake_News_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libaries
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import pickle
from sklearn.linear_model import LogisticRegressionCV
import re
import pandas as pd
import warnings
warnings.filterwarnings("ignore") # Corrected the function name from filterwarmings to filterwarnings

# %%
df = pd.read_csv('covid_fake.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label
# 0  coronavirusmedicalkit.com  Fake
# 1               RudyGiuliani  Fake
# 2                CharlieKirk  Fake
# 3    JoanneWrightForCongress  Fake
# 4    JoanneWrightForCongress  Fake

# %%
df.head(10)
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  CORONA UNMASKED: Chinese Intelligence Officer ...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Basic protective measures against the new coro...
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
# 5                                                NaN
# ...

# %%
df.shape
# Out:
# (1164, 4)

# %%
df['label'].value_counts()
# Out:
# label
# TRUE    584
# Fake    345
# fake    230
# Name: count, dtype: int64

# %%
df.loc[5:15]
# Out:
#                                                 title  \
# 5   CORONA UNMASKED: Chinese Intelligence Officer ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Basic protective measures against the new coro...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Exposing yourself to the sun or to temperature...
# 15  You can recover from the coronavirus disease (...
#
#                                                  text  \
# 5                                                 NaN
# 6   Urgent: Health Bulletin to the Public. Ministr...
# 7   Pls tell ur families, relatives and friendsMOH...
# 8   SERIOUS EXCELLENT ADVICE by Japanese doctors t...
# ...

# %%
df.isna().sum()
# Out:
# title     82
# text      10
# source    20
# label      5
# dtype: int64

# %%
df.loc[df['label'] == 'Fake', ['label']] = 'Fake'
df.loc[df['label'] == 'fake', ['label']] = 'Fake'
df.loc[df['source'] == 'facebook', ['source']] = 'Facebook'
df.text.fillna(df.title, inplace=True)
df.loc[5]['label'] = 'Fake'
df.loc[5]['label'] = 'Fake'

# %%
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label
# 0  coronavirusmedicalkit.com  Fake
# 1               RudyGiuliani  Fake
# 2                CharlieKirk  Fake
# 3    JoanneWrightForCongress  Fake
# 4    JoanneWrightForCongress  Fake

# %%
df.loc[df['label'] == 'Fake', ['label']] = 'FAKE'
df.loc[df['label'] == 'Real', ['label']] = 'FAKE'
df.loc[df['source'] == 'facebook', ['source']] = 'Facebook'
df.text.fillna(df.title, inplace=True)
df.loc[5]['label'] = 'FAKE'
df.loc[15]['label'] = 'TRUE'
df.loc[43]['label'] = 'FAKE'
df.loc[131]['label'] = 'TRUE'
df.loc[242]['label'] = 'FAKE'

df.title.fillna('missing', inplace=True)
df.source.fillna('missing', inplace=True)
df['title_text'] = df['title'] + ' ' + df['text']

# %%
df.isna().sum()
# Out:
# title         0
# text          0
# source        0
# label         0
# title_text    0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# TRUE    586
# FAKE    578
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                            missing
# 2                                            missing
# 3                                            missing
# 4                                            missing
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label  \
# 0  coronavirusmedicalkit.com  FAKE
# 1               RudyGiuliani  FAKE
# 2                CharlieKirk  FAKE
# 3    JoanneWrightForCongress  FAKE
# 4    JoanneWrightForCongress  FAKE
#
#                                           title_text
# ...

# %%
df.head(1)
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
#
#                       source label  \
# 0  coronavirusmedicalkit.com  FAKE
#
#                                           title_text
# 0  Due to the recent outbreak for the Coronavirus...

# %%
df.shape
# Out:
# (1164, 5)

# %% [markdown]
# # PRE-PROCESSING

# %%
df['title_text'][3]
# Out:
# 'missing The Corona virus is a man made virus created in a Wuhan laboratory. Ask @BillGates who financed it.'

# %%
def preprocessor(text):
  text = re.sub('<[^>]*>', '', text)
  text = re.sub(r'<[^\w\s>]','', text)
  text = re.sub(r'[\n]', '', text)
  return text

df['title_text'] = df['title_text'].apply(preprocessor)
df['title_text'][3]
# Out:
# 'missing The Corona virus is a man made virus created in a Wuhan laboratory. Ask @BillGates who financed it.'

# %%
porter = PorterStemmer
def tokenize_porter(text):
  return (porter.stem(word) for word in text.split())

# %% [markdown]
# #TF-IDF

# %%
from nltk.stem.porter import PorterStemmer
import re

# Define the tokenizer function
def tokenizer_porter(text):
    porter = PorterStemmer()
    return [porter.stem(word) for word in text.split()]

# Now, you can use the TfidfVectorizer with the tokenizer_porter
tfidf = TfidfVectorizer(strip_accents=None,
                        lowercase=False,
                        preprocessor=None,
                        tokenizer=tokenizer_porter,
                        use_idf=True,
                        norm='l2',
                        smooth_idf=True)

X = tfidf.fit_transform(df['title_text'])
y = df.label.values

# %%
X.shape
# Out:
# (1164, 47305)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.3, shuffle=False)

# %%
from sklearn.linear_model import LogisticRegressionCV
import pickle
clf = LogisticRegressionCV(cv=5, scoring='accuracy', random_state=0, n_jobs=-1, verbose=0, max_iter=300)
clf.fit(X_train, y_train)
fake_news_model = open('fake_news_model.sav', 'wb')
pickle.dump(clf, fake_news_model)
fake_news_model.close()

# %%
filename = 'fake_news_model.sav'
saved_clf = pickle.load(open(filename, 'rb'))
saved_clf.score(X_test, y_test) # Changed y_text to y_test
# Out:
# 0.94

# %%
#Sample perediction
clf.predict(X_test[59])
# Out:
# array(['FAKE'], dtype=object)

# %%
text = "Corona virus before it reaches lungs"
inp = [text]
vect = tfidf.transform(inp)
prediction = clf.predict(vect)
print(prediction)
# Out:
# ['FAKE']
